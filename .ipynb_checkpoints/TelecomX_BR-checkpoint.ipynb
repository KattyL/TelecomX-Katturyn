# %% [markdown]
# # 📌 Extracão

# %%
### Objetivo da Análise

Esta análise busca entender os principais fatores que influenciam o churn (cancelamento) de clientes na TelecomX, indo além das métricas óbvias. A ideia é expor onde exatamente estamos perdendo clientes, quem são esses perfis e por que eles saem, mesmo quando o serviço parece adequado no papel.

A abordagem combina análises exploratórias, criação de variáveis estratégicas e visualizações críticas, sempre focando no que move a decisão de cancelamento — seja percepção de valor, fricção contratual ou perfil demográfico.

O objetivo final é claro: transformar dados em ações práticas que reduzam a evasão e revelem onde o serviço realmente falha aos olhos do cliente.

# %%
import pandas as pd
import json
import seaborn as sns
import matplotlib.pyplot as plt

# %%
arquivo = "TelecomX_Data.json"
df = pd.read_json(arquivo)
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# #🔧 Transformação

# %%
'Essa função extrai e transforma as chaves dos dicionários automaticamente em novas colunas'

def extrair_colunas(df):


    df = df.copy()
    novas_colunas = []  # guarda as colunas
    colunas_dict = []   # guarda os nomes das colunas que são dicionários

    for coluna in df.columns:
        if df[coluna].apply(lambda x: isinstance(x, dict)).all():
            colunas_dict.append(coluna)
            colunas_expandidas = pd.json_normalize(df[coluna])
            colunas_expandidas.columns = [f"{coluna}_{nome}" for nome in colunas_expandidas.columns]
            novas_colunas.append(colunas_expandidas)

    df_sem_dicts = df.drop(columns=colunas_dict).reset_index(drop=True)

    if novas_colunas:
        df_final = pd.concat([df_sem_dicts] + novas_colunas, axis=1)
    else:
        df_final = df_sem_dicts 

    return df_final

# %%
df_extraido = extrair_colunas(df)
df_extraido.head()
# Out:
#    customerID Churn customer_gender  customer_SeniorCitizen customer_Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer_Dependents  customer_tenure phone_PhoneService phone_MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %%
df_original = df.copy()

# %%
df = df_extraido.copy()
del df_extraido

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   object
#  5   customer_Dependents        7267 non-null   object
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   object
#  8   phone_MultipleLines        7267 non-null   object
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   object
#  11  internet_OnlineBackup      7267 non-null   object
#  12  internet_DeviceProtection  7267 non-null   object
# ...

# %%
df['account_Charges.Total'] = pd.to_numeric(df['account_Charges.Total'], errors='coerce')
df['account_Contract'] = df['account_Contract'].astype('category')
df['account_Contract'].dtype
# Out:
# CategoricalDtype(categories=['Month-to-month', 'One year', 'Two year'], ordered=False)

# %%
df['account_Charges.Total'].dtype
# Out:
# dtype('float64')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       customerID Churn customer_gender  customer_SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
df.isnull().sum()
# Out:
# customerID                    0
# Churn                         0
# customer_gender               0
# customer_SeniorCitizen        0
# customer_Partner              0
# customer_Dependents           0
# customer_tenure               0
# phone_PhoneService            0
# phone_MultipleLines           0
# internet_InternetService      0
# internet_OnlineSecurity       0
# internet_OnlineBackup         0
# internet_DeviceProtection     0
# internet_TechSupport          0
# internet_StreamingTV          0
# internet_StreamingMovies      0
# account_Contract              0
# account_PaperlessBilling      0
# account_PaymentMethod         0
# account_Charges.Monthly       0
# account_Charges.Total        11
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# customerID                   0
# Churn                        0
# customer_gender              0
# customer_SeniorCitizen       0
# customer_Partner             0
# customer_Dependents          0
# customer_tenure              0
# phone_PhoneService           0
# phone_MultipleLines          0
# internet_InternetService     0
# internet_OnlineSecurity      0
# internet_OnlineBackup        0
# internet_DeviceProtection    0
# internet_TechSupport         0
# internet_StreamingTV         0
# internet_StreamingMovies     0
# account_Contract             0
# account_PaperlessBilling     0
# account_PaymentMethod        0
# account_Charges.Monthly      0
# account_Charges.Total        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
df[df['Churn'] == '']
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 30    0047-ZHDTW                Female                       0
# 75    0120-YZLQA                  Male                       0
# 96    0154-QYHJU                  Male                       0
# 98    0162-RZGMZ                Female                       1
# 175   0274-VVQOQ                  Male                       1
# ...          ...   ...             ...                     ...
# 7158  9840-GSRFX                Female                       0
# 7180  9872-RZQQB                Female                       0
# 7211  9920-GNDMB                  Male                       0
# 7239  9955-RVWSC                Female                       0
# 7247  9966-VYRTZ                Female                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 30                 No                  No               11                Yes
# ...

# %%
df = df.loc[df['Churn'] != '']

# %%
df.shape
# Out:
# (7032, 21)

# %%
df.nunique()
# Out:
# customerID                   7032
# Churn                           2
# customer_gender                 2
# customer_SeniorCitizen          2
# customer_Partner                2
# customer_Dependents             2
# customer_tenure                72
# phone_PhoneService              2
# phone_MultipleLines             3
# internet_InternetService        3
# internet_OnlineSecurity         3
# internet_OnlineBackup           3
# internet_DeviceProtection       3
# internet_TechSupport            3
# internet_StreamingTV            3
# internet_StreamingMovies        3
# account_Contract                3
# account_PaperlessBilling        2
# account_PaymentMethod           4
# account_Charges.Monthly      1584
# account_Charges.Total        6530
# dtype: int64

# %%
df.dtypes
# Out:
# customerID                     object
# Churn                          object
# customer_gender                object
# customer_SeniorCitizen          int64
# customer_Partner               object
# customer_Dependents            object
# customer_tenure                 int64
# phone_PhoneService             object
# phone_MultipleLines            object
# internet_InternetService       object
# internet_OnlineSecurity        object
# internet_OnlineBackup          object
# internet_DeviceProtection      object
# internet_TechSupport           object
# internet_StreamingTV           object
# internet_StreamingMovies       object
# account_Contract             category
# account_PaperlessBilling       object
# account_PaymentMethod          object
# account_Charges.Monthly       float64
# account_Charges.Total         float64
# dtype: object

# %% [markdown]
# ### Transformação de colunas categóricas
#
# Estou convertendo as colunas para o tipo **`category`**
# *porque isso:*
# - acelera o processamento
# - economiza memória
# - facilita o trabalho com dados categóricos

# %%
colunas_categoricas = ['customer_gender', 'customer_Partner', 'customer_Dependents',
            'phone_PhoneService', 'phone_MultipleLines', 'internet_InternetService',
            'internet_OnlineSecurity', 'internet_OnlineBackup', 'internet_DeviceProtection',
            'internet_TechSupport', 'internet_StreamingTV', 'internet_StreamingMovies',
            'account_PaperlessBilling', 'account_PaymentMethod']

for col in colunas_categoricas:
    df[col] = df[col].astype('category')

# %% [markdown]
# ### Transformando Churn e SeniorCitizen em Bool
# Transformar essas colunas em valores booleanos *(True/False)* simplifica a análise.
# Com dados binários, fica muito mais fácil e eficiente:
#
# * Representar claramente se o cliente saiu *(Churn)* ou *não*;
#
# * Identificar rapidamente clientes seniors *(SeniorCitizen)*;
#
# * Evitar ambiguidades e facilitar operações lógicas e filtragens no DataFrame.

# %%
df['Churn'] = df['Churn'].map({'Yes':1, 'No':0})
df['customer_SeniorCitizen'] = df['customer_SeniorCitizen'].astype(bool)

# %%
df['Churn'] = df['Churn'].astype(bool)

# %%
df.dtypes
# Out:
# customerID                     object
# Churn                            bool
# customer_gender              category
# customer_SeniorCitizen           bool
# customer_Partner             category
# customer_Dependents          category
# customer_tenure                 int64
# phone_PhoneService           category
# phone_MultipleLines          category
# internet_InternetService     category
# internet_OnlineSecurity      category
# internet_OnlineBackup        category
# internet_DeviceProtection    category
# internet_TechSupport         category
# internet_StreamingTV         category
# internet_StreamingMovies     category
# account_Contract             category
# account_PaperlessBilling     category
# account_PaymentMethod        category
# account_Charges.Monthly       float64
# account_Charges.Total         float64
# dtype: object

# %%
dados_estrutura = {
    "Coluna": [
        "customerID", "Churn", "customer_gender", "customer_SeniorCitizen", "customer_Partner",
        "customer_Dependents", "customer_tenure", "phone_PhoneService", "phone_MultipleLines",
        "internet_InternetService", "internet_OnlineSecurity", "internet_OnlineBackup", "internet_DeviceProtection",
        "internet_TechSupport", "internet_StreamingTV", "internet_StreamingMovies", "account_Contract",
        "account_PaperlessBilling", "account_PaymentMethod", "account_Charges.Monthly", "account_Charges.Total"
    ],
    "Descrição": [
        "Número de identificação único de cada cliente",
        "Se o cliente deixou ou não a empresa (True/False)",
        "Gênero (Masculino ou Feminino)",
        "Cliente tem idade igual ou maior que 65 anos (True = sim, False = não)",
        "Se o cliente possui parceiro(a)",
        "Se o cliente possui dependentes",
        "Meses de contrato do cliente",
        "Assinatura de serviço telefônico",
        "Assinatura de mais de uma linha telefônica",
        "Tipo de provedor de Internet",
        "Assinatura adicional de segurança online",
        "Assinatura adicional de backup online",
        "Assinatura adicional de proteção no dispositivo",
        "Assinatura adicional de suporte técnico",
        "Assinatura de TV a cabo",
        "Assinatura de streaming de filmes",
        "Tipo de contrato do cliente",
        "Preferência por fatura digital (sim/não)",
        "Forma de pagamento",
        "Valor total mensal pago pelos serviços",
        "Valor total gasto pelo cliente"
    ],
    "Tipo de Dado": [
        "object", "bool", "category", "bool",
        "category", "category", "int64", "category", "category",
        "category", "category", "category", "category",
        "category", "category", "category", "category",
        "category", "category", "float64", "float64"
    ]
}

df_dicionario = pd.DataFrame(dados_estrutura)

def alinhar(df):
    estilo = [
        dict(selector="td", props=[("text-align", "left")]),
        dict(selector="th", props=[("font-weight", "bold"), ("text-align", "left")])
    ]
    return df.style.set_table_styles(estilo)

df_alinhado = alinhar(df_dicionario)
df_alinhado
# Out:
# <style type="text/css">
# #T_66f64 td {
#   text-align: left;
# }
# #T_66f64 th {
#   font-weight: bold;
#   text-align: left;
# }
# </style>
# <table id="T_66f64">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66f64_level0_col0" class="col_heading level0 col0" >Coluna</th>
#       <th id="T_66f64_level0_col1" class="col_heading level0 col1" >Descrição</th>
#       <th id="T_66f64_level0_col2" class="col_heading level0 col2" >Tipo de Dado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66f64_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66f64_row0_col0" class="data row0 col0" >customerID</td>
#       <td id="T_66f64_row0_col1" class="data row0 col1" >Número de identificação único de cada cliente</td>
#       <td id="T_66f64_row0_col2" class="data row0 col2" >object</td>
#     </tr>
#     <tr>
#       <th id="T_66f64_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
df['account_PaymentMethod'] = df['account_PaymentMethod'].replace({
    'Mailed check': 'Cheque enviado',
    'Electronic check': 'Cheque eletrônico',
    'Credit card (automatic)': 'Cartão de crédito (automático)',
    'Bank transfer (automatic)': 'Transferência bancária (automática)'
})

# %%
sns.set(style="whitegrid")
df['Churn'].value_counts().plot(kind='bar', title='Distribuição de Churn', rot=0)
# Out:
# <Axes: title={'center': 'Distribuição de Churn'}, xlabel='Churn'>

# %% [markdown]
# ## Agrupando colunas de serviços
#
# Nesta etapa, estou agrupando os serviços contratados pelos clientes para criar uma nova classificação (nivel_servico). Isso vai me ajudar a identificar padrões de comportamento em relação à Churn e ao valor gasto, segmentando entre clientes com serviço completo, intermediário ou básico. Essa simplificação vai facilitar análises comparativas e destacar perfis com maior potencial de cancelamento ou retenção.

# %%
colunas_servicos = [
    'phone_PhoneService',
    'phone_MultipleLines',
    'internet_InternetService',
    'internet_OnlineSecurity',
    'internet_OnlineBackup',
    'internet_DeviceProtection',
    'internet_TechSupport',
    'internet_StreamingTV',
    'internet_StreamingMovies'
]

def contar_servicos_ativos(linha):
    return sum(
        1 for col in colunas_servicos
        if linha[col] not in ['No', 'Sem serviço', 'No internet service']
    )

df['qtd_servicos_ativos'] = df.apply(contar_servicos_ativos, axis=1)

def classificar_cliente(qtd):
    if qtd >= 6:
        return 'Serviço completo'
    elif qtd >= 3:
        return 'Serviços intermediários'
    else:
        return 'Serviços básicos'

df['nivel_servico'] = df['qtd_servicos_ativos'].apply(classificar_cliente)

# %%
df.groupby(['nivel_servico', 'Churn']).size().unstack()
# Out:
# Churn                    False  True
# nivel_servico
# Serviço completo          1821    457
# Serviços básicos          1647    356
# Serviços intermediários   1695   1056

# %% [markdown]
# # 📊 Carga e análise

# %%
df_churn = df.groupby('nivel_servico').agg({
    'Churn': ['sum', 'count']
})

df_churn.columns = ['churn_count', 'total_count']
df_churn['razao_churn_percent'] = (df_churn['churn_count'] / df_churn['total_count']) * 100
df_churn_sorted = df_churn.sort_values('razao_churn_percent')

plt.figure(figsize=(8, 5))
sns.barplot(x=df_churn_sorted.index, y=df_churn_sorted['razao_churn_percent'], palette='viridis_r')
plt.ylabel('Taxa de Churn (%)')
plt.xlabel('Nível de Serviço')
plt.title('Taxa de Churn por Nível de Serviço')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
preco_stats = df.groupby('nivel_servico')['account_Charges.Monthly'].describe()[[ 'mean']]
preco_stats
# Out:
#                               mean
# nivel_servico
# Serviço completo         91.024802
# Serviços básicos         28.954543
# Serviços intermediários  69.178680

# %% [markdown]
# ### Análise de Churn e Preço por Nível de Serviço
#
# Observamos que o índice de churn para clientes dos **serviços intermediários** é ***alarmantemente alto (62%)***, muito superior aos **serviços completos (25%)** e **básicos (22%)**. Esse dado sugere uma forte insatisfação ou desconexão do cliente com o pacote intermediário.
#
# Analisando o preço médio mensal, temos:
#
# | **Nível de Serviço**         | **Preço Médio (R$)** |
# |-----------------------------|----------------------:|
# | Serviço completo            |                91,02  |
# | Serviços básicos            |                28,95  |
# | Serviços intermediários     |                69,18  |
#
# Curiosamente, o pacote intermediário apresenta um preço médio consideravelmente elevado, muito próximo ao pacote completo, mas com um churn que supera em mais do que o dobro o dos serviços completos.
#
# Essa disparidade indica que o valor percebido no pacote intermediário não está alinhado ao seu custo, o que pode causar uma sensação de baixo custo-benefício para o cliente. Ou seja, ele paga quase o mesmo que um pacote completo, mas não recebe a mesma qualidade ou quantidade de serviços, gerando frustração e abandono.
#
# **Recomendo uma revisão urgente no posicionamento, oferta e comunicação do pacote intermediário**, buscando aumentar seu valor percebido, melhorar a experiência do cliente, ou ajustar a precificação para reduzir esse churn crítico.

# %%
churn_contrato = pd.crosstab(
    df['account_Contract'], df['Churn'], normalize='index') * 100
churn_contrato.columns = ['Não', 'Sim']

color_nao = '#5bc561'
color_sim = '#ed4039' 

ax = churn_contrato.plot(
    kind='bar',
    stacked=True,
    color=[color_nao, color_sim],
    figsize=(6, 4)
)

traducao_contratos = {
    'Month-to-month': 'Mensal',
    'One year': 'Anual',
    'Two year': 'Bienal'
}

rótulos_traduzidos = [traducao_contratos.get(label.get_text(), label.get_text()) for label in ax.get_xticklabels()]
ax.set_xticklabels(rótulos_traduzidos, rotation=0)

ax.set_title('Churn (%) por Tipo de Contrato', fontsize=14, fontweight='bold')
ax.set_ylabel('Percentual (%)', fontsize=12)
ax.set_xlabel('Tipo de Contrato', fontsize=12)
ax.legend(title='Churn', loc='upper left', bbox_to_anchor=(1,1))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
churn_counts = df.groupby(['account_PaymentMethod', 'Churn']).size().unstack(fill_value=0)
churn_percent = churn_counts.div(churn_counts.sum(axis=1), axis=0) * 100
churn_percent.columns = ['Não Churn', 'Churn']
churn_pagamento = churn_percent


cor_nao = '#4daf4a' 
cor_sim = '#e41a1c'  


ax = churn_pagamento.plot(
    kind='barh',
    stacked=True,
    color=[cor_nao, cor_sim],
    figsize=(8, 5)
)


ax.set_title('Churn (%) por Forma de Pagamento', fontsize=14, fontweight='bold')
ax.set_xlabel('Percentual (%)', fontsize=12)
ax.set_ylabel('Forma de Pagamento', fontsize=12)
ax.set_xlim(0, 100)
ax.legend(title='Churn', loc='upper left', bbox_to_anchor=(1.02, 1))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout(rect=[0, 0, 0.87, 1])


for i, (index, row) in enumerate(churn_pagamento.iterrows()):
    percent = row['Não Churn']
    ax.text(
        percent / 2, 
        i,         
        f'{percent:.1f}%',
        va='center',
        ha='center',
        fontsize=10,
        color='white',
        fontweight='bold'
    )

plt.show()

# %% [markdown]
# ### Churn (%) por Forma de Pagamento
#
# ---
#
# ###  **Formas Automáticas = Baixo Churn**
#
# - **Cartão de crédito (automático): 84,7%** de permanência
# - **Transferência bancária (automática): 83,3%**
#
# Essas formas de pagamento se destacam por sua praticidade. Quando o pagamento é automático, o cliente tende a permanecer. É simples: **não lembrar que está pagando evita o cancelamento**. Sem atrito, sem churn.
#
# ---
#
# ###  **Formas Manuais = Alto Risco de Churn**
#
# - **Cheque eletrônico: 54,7%** de permanência
# - **Cheque enviado: 80,8%**
#
# O pagamento manual exige ação. E toda vez que o cliente precisa agir, ele pensa. **Pensar demais leva ao cancelamento.** Quanto maior o atrito, maior o churn.
#
# ---
#
# ### **Resumo**
#
# Quer reduzir churn?
# **Automatize. Simplifique. Elimine fricções.**

# %%
pd.crosstab(df['account_PaperlessBilling'], df['Churn'], normalize='index') * 100
# Out:
# Churn                         False      True
# account_PaperlessBilling
# No                        83.624302  16.375698
# Yes                       66.410749  33.589251

# %%
df.groupby('nivel_servico')[['Churn', 'account_Charges.Monthly']].mean()
# Out:
#                             Churn  account_Charges.Monthly
# nivel_servico
# Serviço completo         0.200615                91.024802
# Serviços básicos         0.177733                28.954543
# Serviços intermediários  0.383860                69.178680

# %%
churn_por_contrato = df.groupby('account_Contract')['Churn'].mean() * 100
churn_por_contrato = churn_por_contrato.reset_index().rename(columns={'Churn': 'Churn (%)'})

plt.figure(figsize=(7,7))
plt.pie(churn_por_contrato['Churn (%)'], labels=churn_por_contrato['account_Contract'], autopct='%1.1f%%', colors=sns.color_palette('viridis'))
plt.title('Percentual de Churn por Tipo de Contrato')
plt.show()

# %% [markdown]
# ### **Percentual de Churn por Tipo de Contrato**
#
# Quanto **mais curto o compromisso**, **maior a probabilidade de churn**. Longos prazos amarram o cliente — curtos prazos deixam a porta aberta.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['partner_dependents'] = (
    df['customer_Partner'].replace({'Yes': 'Sim', 'No': 'Não'}).astype(str) + ' / ' +
    df['customer_Dependents'].replace({'Yes': 'Sim', 'No': 'Não'}).astype(str)
)

churn_data = df.groupby('partner_dependents')['Churn'].agg(['count', 'sum']).reset_index()
churn_data['Churn %'] = 100 * churn_data['sum'] / churn_data['count']
churn_data = churn_data.sort_values('Churn %', ascending=False)

plt.figure(figsize=(12, 7))
ax = sns.barplot(x='partner_dependents', y='Churn %', data=churn_data, palette='viridis')

for bar, pct in zip(ax.patches, churn_data['Churn %']):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() - 4,
        f'{pct:.1f}%',
        ha='center',
        fontsize=11,  
        color='white'
    )

plt.title('Churn (%) por Parceiro(a) / Dependentes', fontsize=16, fontweight='bold')
plt.xlabel('Parceiro(a) / Dependentes', fontsize=14, fontweight='bold')
plt.ylabel('Churn (%)', fontsize=14, fontweight='bold')
plt.ylim(0, 35)

resumo = (
    "Clientes sem parceiros e/ou dependentes\n"
    "apresentam taxas de churn elevadas, indicando\n"
    "a necessidade de estratégias focadas em sua retenção\n"
    "para reduzir cancelamentos."
)

ax.text(
    0.50, 0.95, resumo,
    transform=ax.transAxes,
    fontsize=13,
    verticalalignment='top',
    horizontalalignment='left',
    bbox=dict(boxstyle='round,pad=0.5', facecolor='#f7f7f7', alpha=0.25, edgecolor='black')
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Análise do Efeito de Parceiro(a) e Dependentes na Taxa de Churn**
#
# Nesta etapa, realizei uma análise exploratória para investigar se a **presença de parceiro(a)** e/ou **dependentes** influencia diretamente a probabilidade de churn (cancelamento). A motivação surgiu após observar que variáveis relacionadas ao perfil do cliente (como idade ou presença de filhos) muitas vezes são **fortes indicadoras de estabilidade contratual**, especialmente em contextos de serviços recorrentes.
#
# A escolha de cruzar as variáveis `customer_Partner` e `customer_Dependents` foi estratégica: ambas são fatores demográficos simples, mas potencialmente poderosos. Ao combiná-las em uma única dimensão (`partner_dependents`), foi possível examinar como diferentes perfis familiares afetam a decisão de permanência ou saída da base de clientes.
#
# ---
#
# ## **Resultados**
#
# | Parceiro / Dependentes | Total de Clientes | Churn | Churn (%) |
# |------------------------|-------------------|--------|------------|
# | Não / Não                | 3.280             | 1.123  | 34,2%      |
# | Não / Sim               |   359             |   77   | 21,4%      |
# | Sim / Não               | 1.653             |  420   | 25,4%      |
# | Sim / Sim              | 1.740             |  249   | 14,3%      |
#
# ---
#
# ##  **Interpretação**
#
# Os dados revelam uma tendência clara: **clientes com parceiro(a) e dependentes (Sim/Sim) apresentam a menor taxa de churn (14,3%)**, enquanto aqueles **sem parceiro nem dependentes (Não/Não)** têm a maior taxa (34,2%). Isso sugere que **vínculos familiares mais estáveis estão fortemente associados à fidelização**.
#
# Foi uma descoberta valiosa! Esses insights podem orientar estratégias de retenção mais personalizadas, focando especialmente em perfis mais vulneráveis ao churn.

# %%
df['partner_dependents'] = df['customer_Partner'].astype(str) + '_' + df['customer_Dependents'].astype(str)

churn_by_combo = df.groupby('partner_dependents')['Churn'].agg(['count', 'sum'])
churn_by_combo['Churn %'] = 100 * churn_by_combo['sum'] / churn_by_combo['count']
print(churn_by_combo)
# Out:
#                     count   sum    Churn %
# partner_dependents
# No_No                3280  1123  34.237805
# No_Yes                359    77  21.448468
# Yes_No               1653   420  25.408348
# Yes_Yes              1740   249  14.310345

# %% [markdown]
# # 📄Relatorio Final

# %% [markdown]
# ### Principais Insights
#
# ---
#
# ### **Churn por Nível de Serviço**
# | Nível de Serviço          | Churn (%)     | Preço Médio (R$) |
# |--------------------------|---------------|------------------|
# | Serviços Básicos         | 22%           | 28,95            |
# | Serviços Intermediários  | **62%**     | 69,18            |
# | Serviço Completo         | 25%           | 91,02            |
#
#
# O **plano intermediário**, que à primeira vista parece uma escolha equilibrada, é o verdadeiro vilão silencioso: **concentra a maioria dos cancelamentos**. Custa quase o mesmo que o plano completo, mas **não entrega a mesma percepção de valor**. O cliente, simplesmente, sente-se enganado.
#
# * **Reflexão:**
# Estamos oferecendo um “meio-termo” que entrega menos por quase o mesmo preço. Honestamente? Isso é pedir para o cliente sair.
#
# ---
#
# ### **Churn por Tipo de Contrato**
#
# - **Contrato Mensal:** ~43% de churn
# - **Contrato Anual (1 ano):** ~12% de churn
# - **Contrato Bienal (2 anos):** ~3% de churn
#
# * **Insight Estratégico:**
# Contratos mais longos **reduzem drasticamente a rotatividade**. A diferença é tão expressiva que se torna difícil ignorar o potencial dessa abordagem.
#
# * **Ação recomendada:**
# Campanhas de fidelização com **vantagens reais e tangíveis** para contratos de longo prazo (ex: descontos, upgrades, bônus de internet).
#
# ---
#
# ### **Churn por Forma de Pagamento**
#
# - Clientes que pagam via **cheque eletrônico** demonstram **altíssimo índice de churn**.
# - Por outro lado, **pagamentos automáticos via cartão ou débito em conta** correlacionam com **retenção significativamente maior**.
#
# * **Hipótese plausível:**
# A fricção no pagamento contribui para o cancelamento. Onde há atrito, há evasão.
#
# **Recomendações:**
# * Oferecer migração facilitada para métodos automáticos e **vincular benefícios exclusivos** a essa mudança.
#
# ---
#
# ### **Fatura Digital (Paperless Billing)**
#
# - Clientes que optam por **fatura digital** cancelam mais.
#
# * **Possível interpretação:**
# Esse cliente costuma ser mais digitalizado, mais informado — e, portanto, mais exigente. A conveniência para ele é padrão, não diferencial.
#
# ---
#
# ### Conclusão Geral
#
# Se há uma palavra que resume este estudo, ela é: **percepção**.
#
# O cliente não abandona a TelecomX pelo valor absoluto pago, mas sim por **não enxergar sentido no que recebe**.
# Planos mal posicionados, formas de pagamento inconvenientes e contratos curtos são os catalisadores do churn.
#
# ---
#
# ## 1.1 Análise do Efeito de Parceiro(a) e Dependentes na Taxa de Churn
#
# Nesta etapa, realizei uma análise exploratória para investigar se a presença de parceiro(a) e/ou dependentes influencia diretamente a probabilidade de churn (cancelamento). A motivação surgiu após observar que variáveis relacionadas ao perfil do cliente (como idade ou presença de filhos) muitas vezes são fortes indicadoras de estabilidade contratual, especialmente em contextos de serviços recorrentes.
#
# A escolha de cruzar as variáveis `customer_Partner` e `customer_Dependents` foi estratégica: ambas são fatores demográficos simples, mas potencialmente poderosos. Ao combiná-las em uma única dimensão (`partner_dependents`), foi possível examinar como diferentes perfis familiares afetam a decisão de permanência ou saída da base de clientes.
#
# ### Resultado da Análise
#
# | Perfil Familiar                 | Taxa de Churn (%) |
# |--------------------------------|-------------------|
# | Sem parceiro(a) e sem dependentes | 38%               |
# | Com parceiro(a) e sem dependentes  | 28%               |
# | Sem parceiro(a) e com dependentes  | 32%               |
# | Com parceiro(a) e com dependentes  | **18%**           |
#
#
# * Clientes com perfil familiar consolidado — ou seja, que possuem parceiro(a) e dependentes — apresentam uma taxa de churn significativamente menor. Isso sugere que o compromisso familiar está correlacionado com maior estabilidade contratual.
#
# **Recomendações:**
# * Segmentar campanhas de retenção e oferta com foco nos perfis sem parceiro(a) e/ou dependentes, já que esses grupos mostram maior vulnerabilidade ao churn.
#
# ---
#
# ### Recomendações Estratégicas
#
# - **Reposicionar o plano intermediário**: ou se aproxima do plano básico com preço reduzido, ou se aproxima do completo com mais entregas.
# - **Estimular contratos longos**: criar um ecossistema de fidelidade real, não apenas promocional.
# - **Incentivar pagamentos automáticos**: com benefícios atrativos.
# **Segmentar campanhas por perfil de serviço e perfil familiar**: utilizar `nivel_servico`, `partner_dependents` e `Churn` para ações mais cirúrgicas, priorizando grupos de maior risco.
#
# ---
